# %%
import matplotlib.pyplot as plt
import numpy as np
import settings as s
# %matplotlib widget
import importlib
importlib.reload(s)
# Out:
# <module 'settings' from '/drBigBoy/darkRadio/daqAnalysisAndExperiments/teledyne/adq3_data_transfer_gpu_nvidia_pyadq/settings.py'>

# %%
powSpec0    = np.load('powSpec0.npy')
powSpec1    = np.load('powSpec1.npy')
freqs       = np.linspace(0,625, len(powSpec0))

# %%
# %matplotlib widget
importlib.reload(s)
plt.close('all')
plt.plot(freqs, 10*np.log10(powSpec0), label = 'ch 0')
plt.plot(freqs, 10*np.log10(powSpec1), label = 'ch 1', alpha = .5)
plt.xlabel('Freq (MHz)')
plt.ylabel('Power (dBm)')
plt.title(f'{s.NOF_BUFFERS_TO_RECEIVE} averages per channel');
plt.legend(loc='upper right');
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

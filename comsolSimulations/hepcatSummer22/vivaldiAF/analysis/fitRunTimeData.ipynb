# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
size = [240, 300, 480, 550, 650, 750]
time = [22, 23, 213, 320, 849, 2190]

# %%
coefs = np.polyfit(size, time, 3)
print()
print(np.poly1d(times))

sizes = np.linspace(0, 1200)
times = np.poly1d(coefs)
plt.scatter(size, time)
plt.plot(sizes, times(sizes))
plt.xlabel('side of cube (mm)')
plt.ylabel('time(seconds)');
# Out:
#            3           2
# 4.274e-05 x - 0.04966 x + 19.26 x - 2370
